# %%
# %matplotlib widget

# %%
0.0776*3.1
# Out:
# 0.24056000000000002

# %%
run multi_G_w_Co.py
# Out:
# SN name:  SN2011fe
# 2.0
# 3448
# [1662, 1782, 1783, 1982, 1983, 2033, 2034, 2128]
# 467
# [0.01151231 0.99644337 0.9920519  0.63465957 0.21728312 0.00821367
#  0.00951219 1.00941763 0.15276731]
# chi2: 0.000196
# FWHM_Fe: 8132.825687, FWHM_Ni: 5802.512874, vshift_Fe: -1066.988508, vshift_Ni: -2384.428858, flux_ratio Ni/Fe: 0.251877, high_ratio Ni/Fe: 3.4236168050723936e-01
# FWHM_Co: 6719, vshift_Co: 2825
# n_Ni/n_Fe = 0.048207
# input 1 to continue, 2 to save and quit, 3 to quit: 3
# SN name:  SN2011fe
# 2.0
# 3374
# [1663, 1783, 1784, 1983, 1984, 2034, 2035, 2134]
# 472
# [0.01133654 0.99673301 0.99280319 0.64035534 0.23156675 0.00821676
#  0.00896843 1.00855136 0.14110488]
# chi2: 0.000208
# FWHM_Fe: 8008.651535, FWHM_Ni: 5804.700235, vshift_Fe: -980.097706, vshift_Ni: -2159.043535, flux_ratio Ni/Fe: 0.270274, high_ratio Ni/Fe: 0.3616222622231045
# FWHM_Co: 6335, vshift_Co: 2565
# n_Ni/n_Fe = 0.051728
# input 1 to continue, 2 to save and quit, 3 to quit: 3
# SN name:  SN2011fe
# ...
